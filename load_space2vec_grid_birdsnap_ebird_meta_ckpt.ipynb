# %%
import torch

# %%
# ckpt = torch.load("pre_trained_models/space2vec_grid/model_birdsnap_ebird_meta_Space2Vec-grid_inception_v3_0.0100_128_0.1000000_360.000_1_512_leakyrelu.pth.tar", map_location=torch.device('cpu'))
ckpt = torch.load("pre_trained_models/space2vec_grid/model_birdsnap_ebird_meta_1.0_Space2Vec-grid_inception_v3_0.0100_128_0.1000000_360.000_1_512_leakyrelu.pth.tar", map_location=torch.device('cpu'))

# %%
ckpt.keys()
# Out:
# dict_keys(['epoch', 'state_dict', 'optimizer', 'params'])

# %%
ckpt["params"]
# Out:
# {'ssi_run_time': 1,
#  'save_results': True,
#  'unsuper_dataset': 'inat_2018',
#  'unsuper_meta_type': 'birdsnap',
#  'dataset': 'birdsnap',
#  'meta_type': 'ebird_meta',
#  'eval_split': 'test',
#  'load_val_op': True,
#  'cnn_model': 'inception_v3',
#  'load_cnn_predictions': True,
#  'load_cnn_features': True,
#  'load_cnn_features_train': True,
#  'load_img': False,
#  'inat2018_resolution': 'standard',
#  'cnn_pred_type': 'full',
#  'sustainbench_num_rbf_anchor_pts': 100,
#  'sustainbench_rbf_kernel_size': 50,
#  'sustainbench_net_dropout': 0.25,
#  'sustainbench_hidden_dim': 128,
#  'mosaiks_net_dropout': 0.1,
#  'mosaiks_hidden_dim': 128,
#  'device': 'cpu',
#  'model_dir': '../pre_trained_models/space2vec_grid/',
#  'num_epochs': 0,
#  'embed_dim_before_regress': 64,
#  'num_epochs_unsuper': 30,
#  'spa_enc_type': 'Space2Vec-grid',
#  'frequency_num': 128,
#  'max_radius': 360.0,
#  'min_radius': 0.1,
#  'num_hidden_layer': 1,
#  'hidden_dim': 512,
# ...
