# %%
import torch

# %% [markdown]
# Yes, previous commits of the rff Birdsnap ebird-meta checkpoint file (model_birdsnap_ebird_meta_rff_inception_v3_0.0020_64_0.1000000_1_512_2.0.pth.tar) were also truncated (same error).
# RuntimeError: PytorchStreamReader failed reading zip archive: failed finding central directory
#
# bf92dabe6f76564536d9e43d7831c77f901f0f78（2024-09-20）  (update pre-trained models)
# f79b091615a1b13a9358be90777ff799c7024f5d（2024-06-07）  (update)
# 3a7b9a8e78d87a852d95946cbadbc34aab5a58a0（2024-06-07）  (backup pretrained models)
# 4434b1c14cebc70d37cdb46900749ad315597e16（2024-06-07）  (backup pretrained models)
#
# Action item: Find previous checkpoints (perhaps stored locally)

# %%
# 2024-09-20
path_bf92da = "pre_trained_models/rff/bf92da_model_birdsnap_ebird_meta_rff_inception_v3_0.0020_64_0.1000000_1_512_2.0.pth.tar"
ckpt_bf92da = torch.load(path_bf92da, map_location=torch.device('cpu'))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[18], line 3
#       1 # 2024-09-20
#       2 path_bf92da = "pre_trained_models/rff/bf92da_model_birdsnap_ebird_meta_rff_inception_v3_0.0020_64_0.1000000_1_512_2.0.pth.tar"
# ----> 3 ckpt_bf92da = torch.load(path_bf92da, map_location=torch.device('cpu'))
#
# File ~/.pyenv/versions/3.13.2/lib/python3.13/site-packages/torch/serialization.py:1507, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1505 orig_position = opened_file.tell()
#    1506 overall_storage = None
# -> 1507 with _open_zipfile_reader(opened_file) as opened_zipfile:
#    1508     if _is_torchscript_zip(opened_zipfile):
#    1509         warnings.warn(
#    1510             "'torch.load' received a zip file that looks like a TorchScript archive"
# ...

# %%
# 2024-06-07
path_f79b09 = "pre_trained_models/rff/f79b09_model_birdsnap_ebird_meta_rff_inception_v3_0.0020_64_0.1000000_1_512_2.0.pth.tar"
ckpt_f79b09 = torch.load(path_f79b09, map_location=torch.device('cpu'))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 3
#       1 # ckpt = torch.load("pre_trained_models/space2vec_grid/model_birdsnap_ebird_meta_Space2Vec-grid_inception_v3_0.0100_128_0.1000000_360.000_1_512_leakyrelu.pth.tar", map_location=torch.device('cpu'))
#       2 path_f79b09 = "pre_trained_models/rff/f79b09_model_birdsnap_ebird_meta_rff_inception_v3_0.0020_64_0.1000000_1_512_2.0.pth.tar"
# ----> 3 ckpt_f79b09 = torch.load(path_f79b09, map_location=torch.device('cpu'))
#
# File ~/.pyenv/versions/3.13.2/lib/python3.13/site-packages/torch/serialization.py:1507, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1505 orig_position = opened_file.tell()
#    1506 overall_storage = None
# -> 1507 with _open_zipfile_reader(opened_file) as opened_zipfile:
#    1508     if _is_torchscript_zip(opened_zipfile):
# ...

# %%
# 2024-06-07
path_3a7b9a = "pre_trained_models/rff/3a7b9a_model_birdsnap_ebird_meta_rff_inception_v3_0.0020_64_0.1000000_1_512_2.0.pth.tar"
ckpt_3a7b9a = torch.load(path_3a7b9a, map_location=torch.device('cpu'))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 2
#       1 path_3a7b9a = "pre_trained_models/rff/3a7b9a_model_birdsnap_ebird_meta_rff_inception_v3_0.0020_64_0.1000000_1_512_2.0.pth.tar"
# ----> 2 ckpt_3a7b9a = torch.load(path_3a7b9a, map_location=torch.device('cpu'))
#
# File ~/.pyenv/versions/3.13.2/lib/python3.13/site-packages/torch/serialization.py:1507, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1505 orig_position = opened_file.tell()
#    1506 overall_storage = None
# -> 1507 with _open_zipfile_reader(opened_file) as opened_zipfile:
#    1508     if _is_torchscript_zip(opened_zipfile):
#    1509         warnings.warn(
#    1510             "'torch.load' received a zip file that looks like a TorchScript archive"
#    1511             " dispatching to 'torch.jit.load' (call 'torch.jit.load' directly to"
#    (...)
# ...

# %%
# 2024-06-07
path_4434b1 = "pre_trained_models/rff/3a7b9a_model_birdsnap_ebird_meta_rff_inception_v3_0.0020_64_0.1000000_1_512_2.0.pth.tar"
ckpt_4434b1 = torch.load(path_3a7b9a, map_location=torch.device('cpu'))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 2
#       1 path_4434b1 = "pre_trained_models/rff/3a7b9a_model_birdsnap_ebird_meta_rff_inception_v3_0.0020_64_0.1000000_1_512_2.0.pth.tar"
# ----> 2 ckpt_4434b1 = torch.load(path_3a7b9a, map_location=torch.device('cpu'))
#
# File ~/.pyenv/versions/3.13.2/lib/python3.13/site-packages/torch/serialization.py:1507, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1505 orig_position = opened_file.tell()
#    1506 overall_storage = None
# -> 1507 with _open_zipfile_reader(opened_file) as opened_zipfile:
#    1508     if _is_torchscript_zip(opened_zipfile):
#    1509         warnings.warn(
#    1510             "'torch.load' received a zip file that looks like a TorchScript archive"
#    1511             " dispatching to 'torch.jit.load' (call 'torch.jit.load' directly to"
#    (...)
# ...

# %%
import os
print(os.path.getsize(path_bf92da), os.path.getsize(path_f79b09), os.path.getsize(path_3a7b9a), os.path.getsize(path_4434b1))
# Out:
# 8650752 8650752 7602176 7602176
