# %%
import torch

# %% [markdown]
# FAIL TO LOAD. This file is regular Torch ckpt, but corrupted/truncated. Confirmed that the original ckpt on remote repo is the problematic file (https://github.com/seai-lab/TorchSpatial/blob/main/pre_trained_models/sphere2vec_sphereCplus/model_birdsnap_ebird_meta_Sphere2Vec-sphereC%2B_inception_v3_0.0010_64_0.0001000_1_512.pth.tar); the downloading process was error free.

# %%
# ckpt = torch.load("pre_trained_models/space2vec_grid/model_birdsnap_ebird_meta_Space2Vec-grid_inception_v3_0.0100_128_0.1000000_360.000_1_512_leakyrelu.pth.tar", map_location=torch.device('cpu'))
ckpt = torch.load("pre_trained_models/sphere2vec_sphereCplus/model_birdsnap_ebird_meta_1.0_Sphere2Vec-sphereC+_inception_v3_0.0010_64_0.0001000_1.000_1_512.pth.tar", 
                  map_location=torch.device('cpu'),
                  use_new_zipfile_serialization=False
                  )
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 2
#       1 # ckpt = torch.load("pre_trained_models/space2vec_grid/model_birdsnap_ebird_meta_Space2Vec-grid_inception_v3_0.0100_128_0.1000000_360.000_1_512_leakyrelu.pth.tar", map_location=torch.device('cpu'))
# ----> 2 ckpt = torch.load("pre_trained_models/sphere2vec_sphereCplus/model_birdsnap_ebird_meta_1.0_Sphere2Vec-sphereC+_inception_v3_0.0010_64_0.0001000_1.000_1_512.pth.tar",
#       3                   map_location=torch.device('cpu'),
#       4                   use_new_zipfile_serialization=False
#       5                   )
#
# File ~/.pyenv/versions/3.13.2/lib/python3.13/site-packages/torch/serialization.py:1507, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1505 orig_position = opened_file.tell()
#    1506 overall_storage = None
# ...

# %%
import os
print(os.path.getsize("pre_trained_models/sphere2vec_sphereCplus/model_birdsnap_ebird_meta_1.0_Sphere2Vec-sphereC+_inception_v3_0.0010_64_0.0001000_1.000_1_512.pth.tar"))
# Out:
# 8650752

# %%
"pre_trained_models/sphere2vec_sphereCplus/model_birdsnap_ebird_meta_1.0_Sphere2Vec-sphereC+_inception_v3_0.0010_64_0.0001000_1.000_1_512.pth.tar"
# Out:
# 'pre_trained_models/sphere2vec_sphereCplus/model_birdsnap_ebird_meta_1.0_Sphere2Vec-sphereC+_inception_v3_0.0010_64_0.0001000_1.000_1_512.pth.tar'

# %%
# !file pre_trained_models/sphere2vec_sphereCplus/model_birdsnap_ebird_meta_1.0_Sphere2Vec-sphereC+_inception_v3_0.0010_64_0.0001000_1.000_1_512.pth.tar
# !ls -lh pre_trained_models/sphere2vec_sphereCplus/model_birdsnap_ebird_meta_1.0_Sphere2Vec-sphereC+_inception_v3_0.0010_64_0.0001000_1.000_1_512.pth.tar
# !tar -tf pre_trained_models/sphere2vec_sphereCplus/model_birdsnap_ebird_meta_1.0_Sphere2Vec-sphereC+_inception_v3_0.0010_64_0.0001000_1.000_1_512.pth.tar | head
# Out:
# pre_trained_models/sphere2vec_sphereCplus/model_birdsnap_ebird_meta_1.0_Sphere2Vec-sphereC+_inception_v3_0.0010_64_0.0001000_1.000_1_512.pth.tar: Zip archive data, at least v0.0 to extract, compression method=store
# -rw-r--r--@ 1 bolongtang  staff   8.3M Apr 27 18:49 pre_trained_models/sphere2vec_sphereCplus/model_birdsnap_ebird_meta_1.0_Sphere2Vec-sphereC+_inception_v3_0.0010_64_0.0001000_1.000_1_512.pth.tar
# archive/data.pkl
# archive/data/0
# archive/data/1
# archive/data/10
# archive/data/11
# archive/data/12
# archive/data/13
# archive/data/14
# archive/data/15
# archive/data/16
# tar: Truncated ZIP file data
# tar: Error exit delayed from previous errors.

# %% [markdown]
# keyword: Zip archive data

# %%
ckpt["params"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 ckpt["params"]
#
# NameError: name 'ckpt' is not defined
