# %%
import torch
import numpy

# %%
torch.serialization.safe_globals([numpy.core.multiarray.scalar])
# Out:
# /var/folders/rx/ln31tkt933s4gjs2g01hxj200000gn/T/ipykernel_50508/3257640254.py:1: DeprecationWarning: numpy.core is deprecated and has been renamed to numpy._core. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.multiarray.
#   torch.serialization.safe_globals([numpy.core.multiarray.scalar])

# %%
torch.serialization.add_safe_globals([numpy.core.multiarray.scalar])
# Out:
# /var/folders/rx/ln31tkt933s4gjs2g01hxj200000gn/T/ipykernel_50508/1724393424.py:1: DeprecationWarning: numpy.core is deprecated and has been renamed to numpy._core. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.multiarray.
#   torch.serialization.add_safe_globals([numpy.core.multiarray.scalar])

# %%
# ckpt = torch.load("pre_trained_models/rbf/model_birdsnap_ebird_meta_rbf_inception_v3_0.0005_64_0.0005000_1_512_200_2.0.pth.tar", map_location=torch.device('cpu'), weights_only = False)
ckpt = torch.load("pre_trained_models/rbf/model_birdsnap_ebird_meta_1.0_rbf_inception_v3_0.0005_64_0.0005000_1.000_1_512_200_2.0.pth.tar", map_location=torch.device('cpu'), weights_only = False)

# %%
ckpt.keys()
# Out:
# dict_keys(['epoch', 'state_dict', 'optimizer', 'params'])

# %%
ckpt["params"]
# Out:
# {'ssi_run_time': 1,
#  'save_results': True,
#  'unsuper_dataset': 'inat_2018',
#  'unsuper_meta_type': 'birdsnap',
#  'dataset': 'birdsnap',
#  'meta_type': 'ebird_meta',
#  'eval_split': 'test',
#  'load_val_op': True,
#  'cnn_model': 'inception_v3',
#  'load_cnn_predictions': True,
#  'load_cnn_features': True,
#  'load_cnn_features_train': True,
#  'load_img': False,
#  'inat2018_resolution': 'standard',
#  'cnn_pred_type': 'full',
#  'sustainbench_num_rbf_anchor_pts': 100,
#  'sustainbench_rbf_kernel_size': 50,
#  'sustainbench_net_dropout': 0.25,
#  'sustainbench_hidden_dim': 128,
#  'mosaiks_net_dropout': 0.1,
#  'mosaiks_hidden_dim': 128,
#  'device': 'cpu',
#  'model_dir': '../pre_trained_models/rbf/',
#  'num_epochs': 0,
#  'embed_dim_before_regress': 64,
#  'num_epochs_unsuper': 30,
#  'spa_enc_type': 'rbf',
#  'frequency_num': 64,
#  'max_radius': 1.0,
#  'min_radius': 0.0005,
#  'num_hidden_layer': 1,
#  'hidden_dim': 512,
#  'num_rbf_anchor_pts': 200,
# ...
